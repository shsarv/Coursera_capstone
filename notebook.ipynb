# %% [markdown]
# # Applied Data Science Capstone
#
# _Capstone Notebook by Diego Carrasco_
#
# This Notebook will be mainly used fot the Capstone project.

# %%
import pandas as pd
import numpy as np

print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
